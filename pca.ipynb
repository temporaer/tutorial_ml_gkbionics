# %% [markdown]
# Generating Data
# ===============

# %%
D = np.random.multivariate_normal([1,2], np.arange(4).reshape(2,2), size=100)

# %% [markdown]
# Let's have a look at the raw data first...

# %%
np.set_printoptions(4, suppress=True)
print D[:10,:]
# Out:
# [[ 1.3247  3.108 ]
#  [ 0.2121  3.9919]
#  [ 1.2201  3.1526]
#  [ 1.0731  3.7755]
#  [ 1.4649  2.8625]
#  [ 2.6694  5.2349]
#  [ 2.3725  2.8715]
#  [ 0.7716  2.2571]
#  [-0.6035 -0.1601]
#  [ 0.276   2.972 ]]

# %% [markdown]
# Do you see a relationship between the two columns? Since this is two-dimensional, we can plot the data, which allows us to see the relationship.

# %%
plt.figure(figsize=(4,4))
plt.scatter(D[:,0], D[:,1])
plt.axis('equal')
# Out:
# (-3.0, 5.0, -4.0, 8.0)

# %% [markdown]
# We can also have a look at the covariance matrix

# %% [markdown]
# Running PCA
# ===========
#
# We would now like to analyze the directions in which the data varies most. For that, we
#
# 1. place the point cloud in the center (0,0) and
# 2. rotate it, such that the direction with most variance is parallel to the x-axis.
#
# Both steps can be done using PCA, which is conveniently available in sklearn.
#
# We start by loading the PCA class from the sklearn package and creating an instance of the class:

# %%
from sklearn.decomposition import PCA
pca = PCA()

# %% [markdown]
# Now, `pca` is an object which has a function `pca.fit_transform(x)` which performs both steps from above to its argument `x`, and returns the centered and rotated version of `x`.

# %%
E = pca.fit_transform(D)

# %%
plt.figure(figsize=(4,4))
plt.scatter(E[:,0], E[:,1])
plt.axis('equal')
plt.gca().set_aspect('equal')

# %% [markdown]
# The covariances between different axes should be zero now. We can double-check by having a look at the non-diagonal entries of the covariance matrix:

# %%
print np.cov(E, rowvar=False)
# Out:
# [[ 4.275 -0.   ]
#  [-0.     0.537]]

# %% [markdown]
# High-Dimensional Data
# =====================
#
# Our small example above was very easy, since we could get insight into the data by simply plotting it. This approach will not work once you have more than 3 dimensions, let's say four:

# %%
D = np.random.multivariate_normal([1,2], np.arange(4).reshape(2,2), size=100)
D = np.dot(D,np.random.uniform(1,3,(2,4))*np.random.randint(0,2,(2,4))*2-1)

# %% [markdown]
# Lets look at the data again. First, the raw data:

# %%
print D[:10]
# Out:
# [[  6.099   33.8134 -12.5298  23.8508]
#  [  1.6005   4.1789  -1.5793   2.4449]
#  [  0.8322   7.6884  -2.8288   5.7525]
#  [  5.9318  26.061   -9.7018  17.6515]
#  [  4.799   11.6846  -4.4276   6.6437]
#  [  3.5636   6.4335  -2.4713   3.1109]
#  [  1.4722   3.7557  -1.4206   2.1772]
#  [  2.4354  12.0877  -4.4884   8.3747]
#  [  1.7888  11.3674  -4.2028   8.1735]
#  [  1.8535  12.5237  -4.626    9.0746]]

# %% [markdown]
# That one is more tricky. See anything? We can also try plot a few two-dimensional projections:

# %%
plt.figure(figsize=(8,8))
for i in xrange(4):
    for j in xrange(4):
        plt.subplot(4, 4, i * 4 + j + 1)
        plt.scatter(D[:,i], D[:,j])
        plt.axis('equal')
        plt.gca().set_aspect('equal')

# %%
E = pca.fit_transform(D)
print E[:10,:]
# Out:
# [[-34.7368  -2.319    0.       0.    ]
#  [  3.6139   0.087   -0.      -0.    ]
#  [ -1.0985  -1.7021   0.      -0.    ]
#  [-24.5717  -0.5224  -0.      -0.    ]
#  [ -5.8291   1.8583   0.      -0.    ]
#  [  0.9089   1.778    0.      -0.    ]
#  [  4.1532   0.0473   0.      -0.    ]
#  [ -6.669   -0.9778   0.      -0.    ]
#  [ -5.8074  -1.5405   0.      -0.    ]
#  [ -7.3184  -1.7625   0.      -0.    ]]

# %%
plt.figure(figsize=(4,4))
plt.scatter(E[:,0], E[:,1])
plt.axis('equal')
plt.gca().set_aspect('equal')

# %%
plt.figure(figsize=(8,8))
for i in xrange(4):
    for j in xrange(4):
        plt.subplot(4, 4, i * 4 + j + 1)
        plt.scatter(E[:,i], E[:,j])
        plt.gca().set_xlim(-40,40)
        plt.gca().set_ylim(-40,40)
        plt.axis('equal')
        plt.gca().set_aspect('equal')

# %% [markdown]
# Dimension Reduction with PCA
# ============================
#
# We can see that there are actually only two dimensions in the dataset.
#
# Let's throw away even more data -- the second dimension -- and reconstruct the original data in `D`.

# %%
pca = PCA(1) # only keep one dimension!
E = pca.fit_transform(D)
print E[:10,:]
# Out:
# [[-34.7368]
#  [  3.6139]
#  [ -1.0985]
#  [-24.5717]
#  [ -5.8291]
#  [  0.9089]
#  [  4.1532]
#  [ -6.669 ]
#  [ -5.8074]
#  [ -7.3184]]

# %% [markdown]
# Now lets plot the reconstructed data and compare to the original data D. We plot the original data in red, and the reconstruction with only one dimension in blue:

# %%
D_reconstructed = pca.inverse_transform(E)
plt.figure(figsize=(8,8))
for i in xrange(4):
    for j in xrange(4):
        plt.subplot(4, 4, i * 4 + j + 1)
        plt.scatter(D[:,i], D[:,j],c='r')
        plt.scatter(D_reconstructed[:,i], D_reconstructed[:,j],c='b')
        plt.axis('equal')
        plt.gca().set_aspect('equal')
